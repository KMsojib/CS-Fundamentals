# %% [markdown]
# # Mathematics

# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
a + 2
# Out:
# array([5, 6, 7, 8])

# %%
a - 2
# Out:
# array([1, 2, 3, 4])

# %%
a * 2
# Out:
# array([ 6,  8, 10, 12])

# %%
a / 2
# Out:
# array([1.5, 2. , 2.5, 3. ])

# %%
b = np.array([1,0,1,0])
a + b
# Out:
# array([4, 4, 6, 6])

# %%
a ** 2
# Out:
# array([ 9, 16, 25, 36])

# %%
# Take the Sin
np.sin(a)
# Out:
# array([ 0.14112001, -0.7568025 , -0.95892427, -0.2794155 ])

# %%
np.cos(a)
# Out:
# array([-0.9899925 , -0.65364362,  0.28366219,  0.96017029])
